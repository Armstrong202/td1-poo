# %% [markdown]
# ### Exercise 1 : Somme, différence, produi

# %%
a = int(input("Entrez le premier entier : "))
b = int(input("Entrez le deuxième entier : "))

print("Somme :", a + b)
print("Différence :", a - b)
print("Produit :", a * b)
# Out:
# Somme : 582
# Différence : -114
# Produit : 81432

# %% [markdown]
# ### exercise 2 :Tarif réduit

# %%
age = int(input("Entrez votre âge : "))

if age < 26:
    print("Vous avez droit au tarif réduit.")
else:
    print("Vous n'avez pas droit au tarif réduit.")
# Out:
# Vous n'avez pas droit au tarif réduit.

# %% [markdown]
# ### EXERCICE 3 : Départements Île-de-France

# %%
departement = int(input("Entrez votre numéro de département (1 à 99) : "))

if 1 <= departement <= 99:
    if departement in [75, 77, 78, 91, 92, 93, 94]:
        print("Vous habitez en Île-de-France.")
    else:
        print("Vous n'habitez pas en Île-de-France.")
else:
    print("Numéro de département invalide (doit être entre 1 et 99).")
# Out:
# Numéro de département invalide (doit être entre 1 et 99).

# %% [markdown]
# ### EXERCICE 4 : Signe du produit

# %%
x = int(input("Entrez le premier nombre : "))
y = int(input("Entrez le deuxième nombre : "))

if x == 0 or y == 0:
    print("Le produit est nul.")
elif (x > 0 and y > 0) or (x < 0 and y < 0):
    print("Le produit est positif.")
else:
    print("Le produit est négatif.")
# Out:
# Le produit est positif.

# %% [markdown]
# ### EXERCICE 5 : Tarification dégressive

# %%
quantite = int(input("Entrez la quantité d'articles : "))

if quantite <= 10:
    prix_unitaire = 150
elif 10 < quantite <= 49:
    prix_unitaire = 135
else:
    prix_unitaire = 110

montant = quantite * prix_unitaire
print("Quantité :", quantite)
print("Prix unitaire :", prix_unitaire, "€")
print("Montant total :", montant, "€")
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[23], line 1
# ----> 1 quantite = int(input("Entrez la quantité d'articles : "))
#       3 if quantite <= 10:
#       4     prix_unitaire = 150
#
# ValueError: invalid literal for int() with base 10: ''

# %% [markdown]
# ### EXERCICE 6 : Compteur + Pair/Impaire

# %%
import java.util.Scanner;

public class util.Scanner {
    public static void main(String[] args) {
        Scanner sc = new Scanner(System.in);

        // Partie 1 : Compteur simple de 1 à N
        System.out.print("Entrez un nombre N : ");
        int N = sc.nextInt();

        System.out.println("Comptage de 1 à " + N + " :");
        for (int i = 1; i <= N; i++) {
            System.out.print(i + " ");
        }
        System.out.println();

        // Partie 2 : Pair ou impair + les 10 suivants
        System.out.print("Entrez un chiffre : ");
        int chiffre = sc.nextInt();

        if (chiffre % 2 == 0) {
            System.out.println("Nombre pair");
            for (int i = 0; i < 10; i++) {
                System.out.print((chiffre + i * 2) + " ");
            }
        } else {
            System.out.println("Nombre impair");
            for (int i = 0; i < 10; i++) {
                System.out.print((chiffre + i * 2) + " ");
            }
        }
        System.out.println();
    }
}

# %% [markdown]
# ###  EXERCICE 8 : Multiple

# %%
import java.util.Scanner;

public class Exercice8 {
    public static void main(String[] args) {
        // Partie 1 : Multiples de 5 jusqu'à 50
        System.out.println("Multiples de 5 jusqu'à 50 :");
        for (int i = 5; i <= 50; i += 5) {
            System.out.print(i + " ");
        }
        System.out.println();

        // Partie 2 : Multiples d'un nombre choisi par l'utilisateur
        Scanner sc = new Scanner(System.in);
        System.out.print("Entrez un nombre : ");
        int nombre = sc.nextInt();
        System.out.print("Entrez la limite max : ");
        int max = sc.nextInt();

        System.out.println("Multiples de " + nombre + " jusqu'à " + max + " :");
        for (int i = nombre; i <= max; i += nombre) {
            System.out.print(i + " ");
        }
        System.out.println();
    }
}
# Out:
#   Cell In[24], line 5
#     // Partie 1 : Multiples de 5 jusqu'à 50
#                                       ^
# SyntaxError: unterminated string literal (detected at line 5)

# %% [markdown]
# ### EXERCICE 9 : Devinette

# %%
import java.util.Scanner;

public class Exercice9 {
    public static void main(String[] args) {
        Scanner sc = new Scanner(System.in);

        // Tirer un nombre aléatoire entre 1 et 10
        int nbAleatoire = (int) (Math.random() * 10 + 1);
        int essais = 0;
        int saisie;

        System.out.println("Devinez le nombre (entre 1 et 10) :");

        // Boucle jusqu'à ce que l'utilisateur trouve
        do {
            saisie = sc.nextInt();
            essais++;
            if (saisie != nbAleatoire) {
                System.out.println("Raté, essayez encore !");
            }
        } while (saisie != nbAleatoire);

        System.out.println("Bravo ! Vous avez trouvé en " + essais + " essais.");
    }
}
# Out:
#   Cell In[25], line 3
#     public class Exercice9 {
#            ^
# SyntaxError: invalid syntax

# %% [markdown]
# ## Tp 2 : Chaines de caractere

# %% [markdown]
# ### Exercice 1 : Groupe d’un verbe

# %%
import java.util.Scanner;

public class Exercice1 {
    public static void main(String[] args) {
        Scanner sc = new Scanner(System.in);
        System.out.print("Entrez un verbe : ");
        String verbe = sc.nextLine().toLowerCase();

        if (verbe.endsWith("er")) {
            System.out.println("C'est un verbe du 1er groupe.");
        } else if (verbe.endsWith("ir")) {
            System.out.println("C'est un verbe du 2ème groupe.");
        } else if (verbe.endsWith("oir") || verbe.endsWith("oire")) {
            System.out.println("C'est un verbe du 3ème groupe.");
        } else {
            System.out.println("Verbe non reconnu.");
        }
    }
}
# Out:
#   Cell In[26], line 3
#     public class Exercice1 {
#            ^
# SyntaxError: invalid syntax

# %% [markdown]
# ### Longueur d’une phrase

# %%
import java.util.Scanner;

public class Exercice2 {
    public static void main(String[] args) {
        Scanner sc = new Scanner(System.in);
        System.out.print("Entrez une phrase : ");
        String phrase = sc.nextLine();

        int longueur = phrase.length();

        if (longueur < 20) {
            System.out.println("Phrase courte");
        } else if (longueur < 50) {
            System.out.println("Phrase moyenne");
        } else {
            System.out.println("Phrase longue");
        }
    }
}
# Out:
#   Cell In[15], line 3
#     public class Exercice2 {
#            ^
# SyntaxError: invalid syntax

# %% [markdown]
#  ### Exercice 3 : Analyse d’un mot

# %%
import java.util.Scanner;

public class Exercice3 {
    public static void main(String[] args) {
        Scanner sc = new Scanner(System.in);
        System.out.print("Entrez un mot : ");
        String mot = sc.nextLine();

        char premiere = mot.charAt(0);
        char derniere = mot.charAt(mot.length() - 1);
        int nbLettres = mot.length();

        System.out.println("Première lettre : " + premiere);
        System.out.println("Dernière lettre : " + derniere);
        System.out.println("Nombre de lettres : " + nbLettres);
    }
}

# %% [markdown]
# ### Exercice 4 : Nom et prénom formatés

# %%
import java.util.Scanner;

public class Exercice4 {
    public static void main(String[] args) {
        Scanner sc = new Scanner(System.in);
        System.out.print("Entrez votre nom : ");
        String nom = sc.nextLine();
        System.out.print("Entrez votre prénom : ");
        String prenom = sc.nextLine();

        String nomMaj = nom.toUpperCase();
        String prenomFormat = prenom.substring(0,1).toUpperCase() + prenom.substring(1).toLowerCase();

        System.out.println(nomMaj + " (" + nomMaj.length() + ")");
        System.out.println(prenomFormat + " (" + prenomFormat.length() + ")");
    }
}

# %% [markdown]
# ### Exercice 5 : Couper une phrase

# %%
import java.util.Scanner;

public class Exercice5 {
    public static void main(String[] args) {
        Scanner sc = new Scanner(System.in);
        System.out.print("Entrez une phrase : ");
        String phrase = sc.nextLine();

        if (phrase.length() > 10) {
            String coupe = phrase.substring(0, 10) + "...";
            System.out.println(coupe);
        } else {
            System.out.println(phrase);
        }
    }
}

# %% [markdown]
# ### Exercice 6 : Noms composés

# %%
import java.util.Scanner;

public class Exercice6 {
    public static void main(String[] args) {
        Scanner sc = new Scanner(System.in);
        System.out.print("Entrez votre nom : ");
        String nom = sc.nextLine();
        System.out.print("Entrez votre prénom : ");
        String prenom = sc.nextLine();

        // Nom en majuscule
        String nomMaj = nom.toUpperCase();
        System.out.println(nomMaj + " (" + nomMaj.replace("'", "").length() + ")");

        // Prénom : gérer les composés avec tiret
        String[] parties = prenom.split("-");
        StringBuilder prenomFormat = new StringBuilder();
        for (int i = 0; i < parties.length; i++) {
            String p = parties[i];
            prenomFormat.append(p.substring(0,1).toUpperCase())
                        .append(p.substring(1).toLowerCase());
            if (i < parties.length - 1) {
                prenomFormat.append("-");
            }
        }
        System.out.println(prenomFormat + " (" + prenomFormat.length() + ")");
    }
}

# %% [markdown]
# ### Exercice 7 : Palindrome

# %%
import java.util.Scanner;

public class Exercice7 {
    public static void main(String[] args) {
        Scanner sc = new Scanner(System.in);
        System.out.print("Entrez un mot : ");
        String mot = sc.nextLine().toLowerCase();

        String inverse = new StringBuilder(mot).reverse().toString();

        if (mot.equals(inverse)) {
            System.out.println("C'est un palindrome !");
        } else {
            System.out.println("Ce n'est pas un palindrome.");
        }
    }
}

# %% [markdown]
# ### Exercice 8 : Nombres amis

# %%
def somme_chiffres(n):
    somme = 0
    while n > 0:
        somme += n % 10
        n //= 10
    return somme

nb1 = int(input("Entrez le premier nombre : "))
nb2 = int(input("Entrez le deuxième nombre : "))

somme1 = somme_chiffres(nb1)
somme2 = somme_chiffres(nb2)

print("Somme des chiffres du premier nombre :", somme1)
print("Somme des chiffres du deuxième nombre :", somme2)

if somme1 == somme2:
    print("Ces deux nombres sont amis !")
else:
    print("Ces deux nombres ne sont pas amis.")
}
# Out:
#   Cell In[17], line 21
#     }
#     ^
# SyntaxError: unmatched '}'

# %% [markdown]
# ### Exercice 9 : Figures géométriques

# %%
import java.util.Scanner;

public class FigureGeometrique {
    public static void main(String[] args) {
        Scanner sc = new Scanner(System.in);
        int choix;

        do {
            System.out.println("=== Menu Figures Géométriques ===");
            System.out.println("1. Carré (plein)");
            System.out.println("2. Carré (creux)");
            System.out.println("3. Triangle (plein, aligné à gauche)");
            System.out.println("4. Triangle (creux, aligné à gauche)");
            System.out.println("5. Pyramide (plein, centrée)");
            System.out.println("6. Pyramide (creuse, centrée)");
            System.out.println("7. Quitter");
            System.out.print("Tapez le numéro de votre choix : ");
            choix = lireEntier(sc);

            if (choix >= 1 && choix <= 6) {
                System.out.print("Entrez le nombre de lignes (>= 1) : ");
                int n = lireEntier(sc);
                System.out.println();

                switch (choix) {
                    case 1 -> carrePlein(n);
                    case 2 -> carreCreux(n);
                    case 3 -> triangleGauchePlein(n);
                    case 4 -> triangleGaucheCreux(n);
                    case 5 -> pyramidePleine(n);
                    case 6 -> pyramideCreuse(n);
                }
                System.out.println();
            } else if (choix == 7) {
                System.out.println("Au revoir !");
            } else {
                System.out.println("Choix invalide.\n");
            }
        } while (choix != 7);
    }

    // Lecture sûre d’un entier
    private static int lireEntier(Scanner sc) {
        while (!sc.hasNextInt()) {
            sc.next(); // on ignore la saisie invalide
            System.out.print("Veuillez entrer un entier valide : ");
        }
        return sc.nextInt();
    }

    // 1. Carré plein
    private static void carrePlein(int n) {
        for (int i = 0; i < n; i++) {
            for (int j = 0; j < n; j++) System.out.print("*");
            System.out.println();
        }
    }

    // 2. Carré creux
    private static void carreCreux(int n) {
        if (n <= 1) { // cas limites : 0 ou 1 → même rendu qu’un plein
            carrePlein(n);
            return;
        }
        // Ligne du haut
        ligneEtoiles(n);
        // Lignes intermédiaires
        for (int i = 0; i < n - 2; i++) {
            System.out.print("*");
            for (int j = 0; j < n - 2; j++) System.out.print(" ");
            System.out.println("*");
        }
        // Ligne du bas
        ligneEtoiles(n);
    }

    // 3. Triangle plein (aligné à gauche)
    private static void triangleGauchePlein(int n) {
        for (int i = 1; i <= n; i++) {
            for (int j = 1; j <= i; j++) System.out.print("*");
            System.out.println();
        }
    }

    // 4. Triangle creux (aligné à gauche)
    private static void triangleGaucheCreux(int n) {
        if (n <= 2) { // n=1 ou n=2 → rendu plein
            triangleGauchePlein(n);
            return;
        }
        // Sommet
        System.out.println("*");
        // Corps
        for (int i = 2; i <= n - 1; i++) {
            System.out.print("*");
            for (int j = 0; j < i - 2; j++) System.out.print(" ");
            System.out.println("*");
        }
        // Base
        for (int j = 0; j < n; j++) System.out.print("*");
        System.out.println();
    }

    // 5. Pyramide pleine (centrée)
    private static void pyramidePleine(int n) {
        for (int i = 1; i <= n; i++) {
            int espaces = n - i;
            int etoiles = 2 * i - 1;
            printEspaces(espaces);
            for (int j = 0; j < etoiles; j++) System.out.print("*");
            System.out.println();
        }
    }

    // 6. Pyramide creuse (centrée)
    private static void pyramideCreuse(int n) {
        if (n <= 2) { // n=1 ou n=2 → rendu plein
            pyramidePleine(n);
            return;
        }
        // Sommet
        printEspaces(n - 1);
        System.out.println("*");

        // Corps
        for (int i = 2; i <= n - 1; i++) {
            int espacesGauche = n - i;
            int espacesInterieur = 2 * i - 3; // espace entre les deux *
            printEspaces(espacesGauche);
            System.out.print("*");
            printEspaces(espacesInterieur);
            System.out.println("*");
        }

        // Base
        printEspaces(0);
        ligneEtoiles(2 * n - 1);
    }

    // Utilitaires
    private static void ligneEtoiles(int count) {
        for (int i = 0; i < count; i++) System.out.print("*");
        System.out.println();
    }

    private static void printEspaces(int count) {
        for (int i = 0; i < count; i++) System.out.print(" ");
    }
}

# %% [markdown]
# ##  TP03 – Java : les collections et les structures répétitives

# %% [markdown]
# #### Partie 1 : Tirages aléatoires

# %% [markdown]
# ##### 1. Tirages jusqu’à retrouver un nombre choisi

# %%
import java.util.Scanner;

public class Tirage1 {
    public static void main(String[] args) {
        Scanner sc = new Scanner(System.in);
        System.out.print("Choisissez un nombre entre 1 et 100 : ");
        int cible = sc.nextInt();

        int tirage, coups = 0;
        do {
            tirage = 1 + (int)(Math.random() * 100); // nombre entre 1 et 100
            coups++;
        } while (tirage != cible);

        System.out.println("Nombre trouvé en " + coups + " tirages aléatoires.");
    }
}

# %% [markdown]
# #### 2. Suite pair + deux impairs

# %%
public class Tirage2 {
    public static void main(String[] args) {
        int coups = 0;
        boolean trouve = false;

        while (!trouve) {
            int a = (int)(Math.random() * 1000); // premier nombre
            int b = (int)(Math.random() * 1000); // deuxième
            int c = (int)(Math.random() * 1000); // troisième
            coups++;

            System.out.println(a + "," + b + "," + c);

            if (a % 2 == 0 && b % 2 != 0 && c % 2 != 0) {
                trouve = true;
                System.out.println("Résultat obtenu en " + coups + " coups.");
            }
        }
    }
}

# %% [markdown]
# ### Exercice 1 : Tableaux

# %%
public class Tableaux {
    public static void main(String[] args) {
        int[] tabInt = new int[10];
        int[] tabPair = new int[10];
        int[] tabImpair = new int[10];
        int somme = 0, produit = 1, min = Integer.MAX_VALUE, max = Integer.MIN_VALUE;
        int indexPair = 0, indexImpair = 0;

        // Initialisation
        for (int i = 0; i < tabInt.length; i++) {
            tabInt[i] = (int)(Math.random() * 101); // entre 0 et 100
        }

        // Affichage
        System.out.print("Tableau : ");
        for (int val : tabInt) {
            System.out.print(val + " ");
        }
        System.out.println();

        // Calculs
        for (int val : tabInt) {
            somme += val;
            produit *= val;
            if (val < min) min = val;
            if (val > max) max = val;

            if (val % 2 == 0) {
                tabPair[indexPair++] = val;
            } else {
                tabImpair[indexImpair++] = val;
            }
        }

        System.out.println("Somme = " + somme);
        System.out.println("Produit = " + produit);
        System.out.println("Min = " + min);
        System.out.println("Max = " + max);

        System.out.print("Pairs : ");
        for (int i = 0; i < indexPair; i++) System.out.print(tabPair[i] + " ");
        System.out.println();

        System.out.print("Impairs : ");
        for (int i = 0; i < indexImpair; i++) System.out.print(tabImpair[i] + " ");
        System.out.println();
    }
}
